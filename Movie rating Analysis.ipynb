# %% [markdown]
# Movie rating Analytics (Advanced Visualzation)

# %%
import pandas as pd
import os

# %%
os.getcwd()
# If you want to change the working dircetory
# Out:
# 'e:\\AI & DS\\Projects and Task'

# %%
movies = pd.read_csv(r'E:\AI & DS\Projects and Task\Movie-Rating.csv')
# Reading the csv file

movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Number of rows
# Out:
# 559

# %%
movies.head(10)
# First 10 rows
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
# 5                   2012     Action                         39
# 6             27 Dresses     Comedy                         40
# 7       30 Days of Night     Horror                         50
# 8     30 Minutes or Less     Comedy                         43
# 9                  50/50     Comedy                         93
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'BudgetMillions', 'Year']
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# The same thing we will change genre to category year to category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions
# count    559.000000       559.000000      559.000000
# mean      47.309481        58.744186       50.236136
# std       26.413091        16.826887       48.731817
# min        0.000000         0.000000        0.000000
# 25%       25.000000        47.000000       20.000000
# 50%       46.000000        58.000000       35.000000
# 75%       70.000000        72.000000       65.000000
# max       97.000000        96.000000      300.000000

# %%
# Working with joint plots
from matplotlib import pyplot as plt
import seaborn as sns


# %matplotlib inline
import warnings

warnings.filterwarnings('ignore')

# %%
pip install --upgrade seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings')
# AudienceRatings and CriticRating, AudienceRatings is dominant
# we can see the trend in AudienceRatings and CriticRating

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings', kind = 'hex')

# %%
# Histogram
# <<< chat 1
m1 = sns.displot(movies.AudienceRatings)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.displot(movies.AudienceRatings, bins = 25)

# %%
n1 = plt.hist(movies.AudienceRatings, bins = 15)

# %%
sns.set_style('dark')
# normal distrubution & called as bell curve

n1 = plt.hist(movies.AudienceRatings, bins = 15)

# %%
n2 = plt.hist(movies.CriticRating, bins = 15)
# uniform distrubution

# %%
# <<< Chart 2
# creating stacked histograms & this is bit tough to understand

# %%
# h1 = plt.hist(movies.BudgetMillions)
plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
movies.head(10)
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
# 5                   2012     Action            39               63
# 6             27 Dresses     Comedy            40               71
# 7       30 Days of Night     Horror            50               57
# 8     30 Minutes or Less     Comedy            43               48
# 9                  50/50     Comedy            93               93
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009
# 5             200  2009
# 6              30  2008
# 7              32  2007
# ...

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
# Below plots are stacked histogram beacuse orverlap
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 25)
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 25)
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMillions, bins = 25)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 25)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
          movies[movies.Genre == 'Drama'].BudgetMillions,\
          movies[movies.Genre == 'Thriller'].BudgetMillions,\
          movies[movies.Genre == 'Comedy'].BudgetMillions],
          bins = 25, stacked = True)
plt.show()

# %%
# If you have 100 categories you cannot copy & past all the things
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRatings', fit_reg = False, hue = 'Genre')

# %%
vis2 = sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRatings', fit_reg = False, hue = 'Genre', aspect=1)

# %%
# Kernel Density Estimate plot (KDE PLOT)
# How cn i visualize audience ratings and critic rating. using scatter plot

# %%
k1 = sns.kdeplot(data = movies,x=movies.CriticRating, y = movies.AudienceRatings, shade = True)
# where do u find more density and how density is distributed across the graph
# center point is kernel this is called KDE & insteade of dots is visualize like scatter plot
# we can able to clearly see the spread at the audience ratings

# %%
k2 = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRatings, shade_lowest = False)

# %%
sns.set_style('dark')
k3 = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRatings, shade_lowest = False)

# %%
sns.set_style('white')
k3 = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRatings)

# %%
k4 = sns.kdeplot(x = movies.BudgetMillions, y = movies.CriticRating)

# %%
# subplots

s,ax = plt.subplots(1,2,figsize = (12,6))

# %%
f, ax = plt.subplots(1,2,figsize = (12,6))

k1 = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRatings, ax = ax[0])
k2 = sns.kdeplot(x = movies.BudgetMillions, y = movies.CriticRating, ax = ax[1])

# %%
ax
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRatings'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
# Box plots -

w = sns.boxplot(data = movies, x = 'Genre', y = 'CriticRating', hue = 'Genre')

# %%
z = sns.violinplot(data = movies, x = 'Genre', y = 'CriticRating', hue = 'Genre')
plt.show()
# sns.violinplot , sns.boxplot , sns.swarmplot , sns.catplot , sns.lmplot , sns.jointplot

# %%
w1 =sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating', hue='Year')

# %%
z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating', hue='Year')

# %%
# Creating a Facet grid

g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
# kind of subplot

# %%
plt.scatter(x=movies.CriticRating, y = movies.AudienceRatings)

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings')
# scatter plots are mapped in facet grid

# %%
# you can populate any Types of Charts
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
g = sns.FacetGrid(movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=5, edgecolor="black")
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings', **kws)

# %%
# Python is not vectorized programming language
# Bulding dashboards (dashboard - combination of chats & graphs)

sns.set_style('darkgrid')
f, axes = plt.subplots(2,2, figsize = (15,15))

k1 = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRatings, ax = axes[0,0])
k2 = sns.kdeplot(x = movies.BudgetMillions, y = movies.CriticRating, ax = axes[0,1])

k1.set(xlim = (-20,160))
k2.set(xlim = (-20,160))

z = sns.violinplot(data = movies, x = 'Genre', y = 'CriticRating', hue = 'Genre', ax = axes[1,0])

k4 = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRatings, shade = True, ax = axes[1,1])
k4b = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRatings, cmap='Reds', ax = axes[1,1])
plt.show()

# %%
sns.set_style('dark', {'axes.facecolor': 'black', 'grid.color': 'green', 'grid.linestyle': '--'})
f, axes = plt.subplots(2,2, figsize = (15,15))
# plot (0,0)
k1 = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRatings, \
                 shade = True, shade_lowest = True, cmap = 'inferno', \
                  ax = axes[0,0])

# plot (0,1)
k2 = sns.kdeplot(x = movies.BudgetMillions, y = movies.CriticRating, \
                 shade = True, shade_lowest = False, cmap = 'spring', \
                  ax = axes[0,1])
# plot (1,0)
k3 = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRatings, \
                 shade = False, shade_lowest = True, cmap = 'Blues_r', \
                  ax = axes[1,0])
# plot (1,1)
vi = sns.violinplot(data = movies[movies.Genre == 'Drama'], x = 'Year', \
                    y = 'CriticRating', hue = 'Genre', ax = axes[1,1])
k1.set(xlim = (-50,250))
k2.set(xlim = (-50,250))
plt.show()

# %% [markdown]
# Final discussion
# - Category datatype in python
# - Jointplots
# - Histogram
# - Stacked Histograms
# - KDE plot
# - Subplot
# - Violin plot
# - Factet Grid
# - Building Dashboards
